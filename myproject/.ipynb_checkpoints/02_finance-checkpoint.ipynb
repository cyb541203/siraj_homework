# %% [markdown]
# # 02_05 In 12 minutes: Stocks Analysis with Pandas and Scikit-Learn

# %% [markdown]
# https://towardsdatascience.com/in-12-minutes-stocks-analysis-with-pandas-and-scikit-learn-a8d8a7b50ee7

# %% [markdown]
# [Requirements]
#
# - pip install pandas-datareader
# - pip install matplotlib

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame

# %% [markdown]
# ### 01 Pull the data from Yahoo

# %%
start = datetime.datetime(2010,1,1)
end = datetime.datetime(2017,1,10)

df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-04  116.510002  115.750000  115.849998  116.019997  21118100.0
# 2017-01-05  116.860001  115.809998  115.919998  116.610001  22193600.0
# 2017-01-06  118.160004  116.470001  116.779999  117.910004  31751900.0
# 2017-01-09  119.430000  117.940002  117.949997  118.989998  33561900.0
# 2017-01-10  119.379997  118.300003  118.769997  119.110001  24462100.0
#
#              Adj Close
# Date
# 2017-01-04  111.162437
# 2017-01-05  111.727715
# 2017-01-06  112.973305
# 2017-01-09  114.008080
# 2017-01-10  114.123047

# %% [markdown]
# ### 02 Rolling mean & Return rate

# %% [markdown]
# #### 01 Rolling mean

# %%
close_px = df['Adj Close']
mavg = close_px.rolling(window=100).mean()

mavg.tail()
# Out:
# Date
# 2017-01-04    107.163730
# 2017-01-05    107.249795
# 2017-01-06    107.335924
# 2017-01-09    107.433354
# 2017-01-10    107.533458
# Name: Adj Close, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib

fig, ax = plt. subplots()
fig.set_dpi(300)

style.use('ggplot')

close_px.plot(label='AAPL')

mavg.plot(label='mavg')
plt.legend()

# %% [markdown]
# The Moving Average makes the line smooth and showcase the increasing or decreasing trend of stocks price.

# %% [markdown]
# #### 02 Return Deviation — to determine risk and return

# %% [markdown]
# Formula for Returns

# %% [markdown]
# r_t
